# %%
import pandas as pd
import pandas as pd
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.preprocessing import MinMaxScaler, StandardScaler
df = pd.read_csv("data.csv", delimiter=',')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2044 entries, 0 to 2043
# Data columns (total 16 columns):
#  #   Column                                                                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                                                                        --------------  -----
#  0   Timestamp                                                                                                                                                     2044 non-null   object
#  1   Berapa usia anda saat ini? (cth: 20 tahun)                                                                                                                    2044 non-null   object
#  2   Jenis Kelamin                                                                                                                                                 2044 non-null   object
#  3   Kabupaten/Kota domisili anda                                                                                                                                  2044 non-null   object
#  4   Status Pernikahan anda                                                                                                                                        2044 non-null   object
#  5   Pendidikan terakhir anda                                                                                                                                      2044 non-null   object
#  6   Apa jurusan/program studi anda? (IPA/IPS/Diploma/Sarjana/Magister/Khusus SD-SMP diberi tanda min (-))                                                         2043 non-null   object
#  7   Status pekerjaan anda saat ini                                                                                                                                2044 non-null   object
#  8   Bidang pekerjaan anda saat ini                                                                                                                                2044 non-null   object
#  9   Lama bekerja pada pekerjaan saat ini                                                                                                                          2044 non-null   object
#  10  Apa pekerjaan pertama anda sebelum pekerjaan anda saat ini?                                                                                                   1118 non-null   object
#  11  Apakah pekerjaan sebelumnya sesuai dengan jurusan anda?                                                                                                       1238 non-null   object
#  12  Jika anda pernah bekerja sebelum pekerjaan anda saat ini, berapakah jumlah penghasilan anda dari pekerjaan anda sebelum pekerjaan anda saat ini? (per bulan)  863 non-null    object
#  13  Berapakah jumlah penghasilan dari pekerjaan anda saat ini? (per bulan)                                                                                        2044 non-null   object
#  14  Seberapa sering anda menggunakan ilmu dari pendidikan anda saat bekerja?                                                                                      2044 non-null   object
#  15  Jika anda pernah bekerja sebelumnya, berapa lama anda bekerja di pekerjaan anda sebelumnya?                                                                   906 non-null    object
# dtypes: object(16)
# memory usage: 255.6+ KB
# None

# %%
print("=== INDENTIFIKASI TIPE DATA ===")
numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

print("Kolom numerik:", list(numeric_cols))
print("Kolom kategorikal:", list(categorical_cols))
# Out:
# === INDENTIFIKASI TIPE DATA ===
# Kolom numerik: []
# Kolom kategorikal: ['Timestamp', 'Berapa usia anda saat ini? (cth: 20 tahun)', 'Jenis Kelamin', 'Kabupaten/Kota domisili anda ', 'Status Pernikahan anda', 'Pendidikan terakhir anda', 'Apa jurusan/program studi anda? (IPA/IPS/Diploma/Sarjana/Magister/Khusus SD-SMP diberi tanda min (-))', 'Status pekerjaan anda saat ini', 'Bidang pekerjaan anda saat ini', 'Lama bekerja pada pekerjaan saat ini', 'Apa pekerjaan pertama anda sebelum pekerjaan anda saat ini?', 'Apakah pekerjaan sebelumnya sesuai dengan jurusan anda?', 'Jika anda pernah bekerja sebelum pekerjaan anda saat ini, berapakah jumlah penghasilan anda dari pekerjaan anda sebelum pekerjaan anda saat ini? (per bulan)', 'Berapakah jumlah penghasilan dari pekerjaan anda saat ini? (per bulan)', 'Seberapa sering anda menggunakan ilmu dari pendidikan anda saat bekerja?', 'Jika anda pernah bekerja sebelumnya, berapa lama anda bekerja di pekerjaan anda sebelumnya? ']

# %%
print("=== INFORMASI STATISTIK DESKRIPTIF ===")
print(df.describe())
# Out:
# === INFORMASI STATISTIK DESKRIPTIF ===
#                   Timestamp Berapa usia anda saat ini? (cth: 20 tahun)  \
# count                  2044                                       2044
# unique                 1897                                        106
# top     16/12/2025 13:42:20                                         27
# freq                      3                                        303
#
#        Jenis Kelamin Kabupaten/Kota domisili anda  Status Pernikahan anda  \
# count           2044                          2044                   2044
# unique             2                            30                      2
# top             Pria                          Toba          Belum Menikah
# freq            1099                           451                   1093
#
#        Pendidikan terakhir anda  \
# count                      2044
# unique                        7
# top                     Sarjana
# freq                       1005
#
#        Apa jurusan/program studi anda? (IPA/IPS/Diploma/Sarjana/Magister/Khusus SD-SMP diberi tanda min (-))  \
# count                                                2043
# unique                                                206
# top                                                     -
# freq                                                  226
#
#        Status pekerjaan anda saat ini Bidang pekerjaan anda saat ini  \
# count                            2044                           2044
# unique                             46                             62
# top                    Pegawai Swasta                         Bisnis
# freq                              610                            568
#
#        Lama bekerja pada pekerjaan saat ini  \
# count                                  2044
# unique                                    4
# top                               3-5 Tahun
# freq                                   1014
#
#        Apa pekerjaan pertama anda sebelum pekerjaan anda saat ini?  \
# count                                                1118
# unique                                                195
# top                                               Bertani
# freq                                                   59
#
#        Apakah pekerjaan sebelumnya sesuai dengan jurusan anda?  \
# count                                                1238
# unique                                                  2
# top                                                    Ya
# freq                                                  667
#
#        Jika anda pernah bekerja sebelum pekerjaan anda saat ini, berapakah jumlah penghasilan anda dari pekerjaan anda sebelum pekerjaan anda saat ini? (per bulan)  \
# count                                                 863
# unique                                                  7
# top                                            1 - 3 juta
# freq                                                  392
#
#        Berapakah jumlah penghasilan dari pekerjaan anda saat ini? (per bulan)  \
# count                                                2044
# unique                                                  6
# top                                            3 - 5 juta
# freq                                                  636
#
#        Seberapa sering anda menggunakan ilmu dari pendidikan anda saat bekerja?  \
# count                                                2044
# unique                                                  5
# top                                         Sangat sering
# freq                                                  632
#
#        Jika anda pernah bekerja sebelumnya, berapa lama anda bekerja di pekerjaan anda sebelumnya?
# count                                                 906
# unique                                                  4
# top                                           1 - 3 tahun
# freq                                                  299
